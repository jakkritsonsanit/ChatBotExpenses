# %%
import pandas as pd

# %%
df = pd.read_csv("Expenses.csv")
df
# Out:
#          date             text     money             cate
# 0     1/10/19      นมช็อคโกแลต      Food              NaN
# 1     1/10/19       ข้าวเที่ยง      Food              NaN
# 2     1/10/19     น้ำกระเจี๊ยบ      Food              NaN
# 3     1/10/19             ชานม      Food              NaN
# 4     1/10/19         ข้าวเย็น      Food              NaN
# 5     1/10/19  ค่าอินเตอร์เน็ต      Bill              NaN
# 6     1/10/19      ค่าโทรศัพท์      Bill              NaN
# 7     2/10/19         ข้าวเย็น      Food              NaN
# 8     2/10/19             ชานม      Food              NaN
# 9     2/10/19           หมาล่า      Food              NaN
# 10    3/10/19         ข้าวเย็น      Food              NaN
# 11    3/10/19            ไอติม      Food              NaN
# 12    3/10/19            ตัดผม     Other              NaN
# 13    3/10/19          ซาลาเปา      Food              NaN
# 14    3/10/19          ไส้กรอก      Food              NaN
# ...
